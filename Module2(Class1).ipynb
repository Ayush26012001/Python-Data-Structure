# %% [markdown]
# # Data Structure
# - It the way of organizing and storing the data so that it can be manipulated.
# - Types of DS
# - 1. List
#   2. Tuple
#   3. String
#   4. Set
#   5. Dictionary

# %% [markdown]
# # List
# - Heterogenous in nature.
# - Ordered collection of item.
# - Mutbale in nature.

# %%
num=[1,2,3,4]
type(num)
# Out:
# list

# %%
num[0]
# Out:
# 1

# %%
num[1]
# Out:
# 2

# %%
num[-1]
# Out:
# 4

# %%
num[5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 num[5]
#
# IndexError: list index out of range

# %%
a=[1,2,3,4.2,'tom','banana',True, False]
a
# Out:
# [1, 2, 3, 4.2, 'tom', 'banana', True, False]

# %%
type(a)
# Out:
# list

# %% [markdown]
# # Adding element to list

# %%
a.append("Orange")

# %%
a
# Out:
# [1, 2, 3, 4.2, 'tom', 'banana', True, False, 'Orange']

# %%
a.append("pwSkills")

# %%
a
# Out:
# [1, 2, 3, 4.2, 'tom', 'banana', True, False, 'Orange', 'pwSkills']

# %% [markdown]
# # Removing the element

# %%
a.remove('pwSkills')

# %%
a
# Out:
# [1, 2, 3, 4.2, 'tom', 'banana', True, False, 'Orange']

# %%
a.remove("Orange")
a
# Out:
# [1, 2, 3, 4.2, 'tom', 'banana', True, False]

# %%
b=[[1,2,3],[4,5,6],[7,8,9]]
b
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
type(b)
# Out:
# list

# %%
b[0][1]
# Out:
# 2

# %%
b[1][2]
# Out:
# 6

# %%
b[2][1]
# Out:
# 8

# %%
shoping_list=['apple','banana','Pen','Cake']
shoping_list
# Out:
# ['apple', 'banana', 'Pen', 'Cake']

# %%
shoping_list[0]='Potato'
shoping_list
# Out:
# ['Potato', 'banana', 'Pen', 'Cake']

# %%
for item in shoping_list:
    print(item)
# Out:
# Potato
# banana
# Pen
# Cake

# %%
for item in shoping_list:
    print(item,end=" ")
# Out:
# Potato banana Pen Cake

# %% [markdown]
# # Tuples
# - Immutable
# - Heterogenous in nature.
# - ()  defining tuple

# %%
point=(2,3)
point
# Out:
# (2, 3)

# %%
type(point)
# Out:
# tuple

# %%
t=(1,1.2,3,'ayush',True)
t
# Out:
# (1, 1.2, 3, 'ayush', True)

# %%
emp_name=("Ayush",'Saumya','Sumit','Adhyyan')
emp_name
# Out:
# ('Ayush', 'Saumya', 'Sumit', 'Adhyyan')

# %%
emp_name[0]
# Out:
# 'Ayush'

# %%
emp_name[1]
# Out:
# 'Saumya'

# %%
emp_name[1]='Rahul' #Immutability
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 emp_name[1]='Rahul'
#
# TypeError: 'tuple' object does not support item assignment

# %%
b1=('a','b')
b2=('c','d')
t=(b1,b2)
t
# Out:
# (('a', 'b'), ('c', 'd'))

# %%
for i in t:
    for j in i:
        print(j)
# Out:
# a
# b
# c
# d

# %% [markdown]
# # Sets
# - Unordered collection of unique element
# - s={'red','orange'}
# - Element can't be accessed throw indexing

# %%
s={'red','orange'}
type(s)
# Out:
# set

# %%
s={'red','orange','red','blue','orange'}
s
# Out:
# {'blue', 'orange', 'red'}

# %%
s[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 s[0]
#
# TypeError: 'set' object is not subscriptable

# %% [markdown]
# # Adding and removing element to set

# %%
s.add("skills")

# %%
s
# Out:
# {'blue', 'orange', 'red', 'skills'}

# %%
s.remove('skills')

# %% [markdown]
# # Dictionaries
# - Store the data in the key value pair.

# %%
my_dict={}
type(my_dict)
# Out:
# dict

# %%
d={'keycourse':'DS','duration':200}
d
# Out:
# {'keycourse': 'DS', 'duration': 200}

# %%
d['keycourse']
# Out:
# 'DS'

# %%
d['duration']
# Out:
# 200

# %%
d['keycourse']='DA'

# %%
d
# Out:
# {'keycourse': 'DA', 'duration': 200}

# %%
rest_menu={'PK':400,'HC':500}
rest_menu
# Out:
# {'PK': 400, 'HC': 500}

# %%
rest_menu.keys()
# Out:
# dict_keys(['PK', 'HC'])

# %%
rest_menu.values()
# Out:
# dict_values([400, 500])

# %% [markdown]
# # Array
# - It store homogenous data
# - Similar to list

# %%
from array import array

# %%
array('i',[1,2,3,4])
# Out:
# array('i', [1, 2, 3, 4])

# %% [markdown]
# # String

# %%
s='abc'
type(s)
# Out:
# str

# %%
for i in s:
    print(i)
# Out:
# a
# b
# c
