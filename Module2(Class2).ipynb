# %% [markdown]
# # String
# - String is a sequence of character represent and manipulate textual data.
# - Characters are represented using numerical values
# - ASCII stands for American Standard Code for Information Interchange
# - UTF stand for Unicode transformation format.

# %% [markdown]
# # ASCII representation

# %%
char="A"
ord(char)
# Out:
# 65

# %%
chr(65)
# Out:
# 'A'

# %%
ord('a')
# Out:
# 97

# %%
chr(97)
# Out:
# 'a'

# %%
chr(101)
# Out:
# 'e'

# %% [markdown]
# # Unicode Representation
# - Omega

# %%
'\u03A9'
# Out:
# 'Ω'

# %%
'\u03A3'
# Out:
# 'Σ'

# %%
'\u0973'
# Out:
# 'ॳ'

# %%
'\u0974'
# Out:
# 'ॴ'

# %%
'\u0975'
# Out:
# 'ॵ'

# %% [markdown]
# # Strings

# %%
a='ayush'
b="Saxena"

# %%
a
# Out:
# 'ayush'

# %%
b
# Out:
# 'Saxena'

# %%
type(a)
# Out:
# str

# %%
type(b)
# Out:
# str

# %%
print('I\'m a student')
# Out:
# I'm a student

# %%
print("I'm a student")
# Out:
# I'm a student

# %%
''' I"m a student'''
# Out:
# ' I"m a student'

# %%
''' I'm a student'''
# Out:
# " I'm a student"

# %% [markdown]
# # Concatenation
# - Combining two string.

# %%
"Hello" + " World"
# Out:
# 'Hello World'

# %%
"Hello" - " World"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 "Hello" - " World"
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
s='Hello'
s1='world'
s+", "+s1
# Out:
# 'Hello, world'

# %% [markdown]
# # Extract/ Slicing of String

# %%
a="Ayush Saxena"
a[0]
# Out:
# 'A'

# %%
a[1]
# Out:
# 'y'

# %%
a[-1]
# Out:
# 'a'

# %%
s="I'm a good student"

# %%
s
# Out:
# "I'm a good student"

# %%
s[1:4]
# Out:
# "'m "

# %%
s[0:4]
# Out:
# "I'm "

# %%
s[5:12]
# Out:
# ' good s'

# %%
s[0:] #It will give you till last index
# Out:
# "I'm a good student"

# %%
string2='class'
string2
# Out:
# 'class'

# %%
string2[1]
# Out:
# 'l'

# %%
string2[-1]
# Out:
# 's'

# %%
string2[::-1]
# Out:
# 'ssalc'

# %%
# except last three character
string2[:-2]
# Out:
# 'cla'

# %%
# you want only last character
string2[-3:]
# Out:
# 'ass'

# %%
s3='hello world!'

# %%
s3[0:5]
# Out:
# 'hello'

# %%
s3[0:5:2]
# Out:
# 'hlo'

# %%
s3[::1]
# Out:
# 'hello world!'

# %%
s3[::2]
# Out:
# 'hlowrd'

# %%
s3[::-1]
# Out:
# '!dlrow olleh'

# %%
# String are immutbale
s='pwskills'
s
# Out:
# 'pwskills'

# %%
s[1]='a'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 s[1]='a'
#
# TypeError: 'str' object does not support item assignment

# %%
len(s) # no. of character
# Out:
# 8

# %%
#Modification of String
s='i am a student'

# %%
s.replace('student','teacher')
# Out:
# 'i am a teacher'

# %%
txt='BRB,TTYL,LOL'

# %%
txt.replace("BRB",'Be right back')
# Out:
# 'Be right back,TTYL,LOL'

# %%
a='hello World'
a.lower()
# Out:
# 'hello world'

# %%
a.upper()
# Out:
# 'HELLO WORLD'

# %%
a.title() # First letter of all word will be captalized
# Out:
# 'Hello World'

# %%
b="hi im Playing" 
b.swapcase() #lower to upper and upper to lower
# Out:
# 'HI IM pLAYING'

# %%
# Capitalize means first letter capital
a='ayush saxena'
a.capitalize()
# Out:
# 'Ayush saxena'

# %%
# String Searching
sen='I am a student'
'am' in sen
# Out:
# True

# %%
email='ayush123'
if "@" in email:
    print("valid email")
else:
    print("Invalid")
# Out:
# Invalid

# %%
doc='abc.pdf'
if '.pdf' in doc:
    print("PDF file")
else:
    print("Not a pdf file")
# Out:
# PDF file

# %%
# String Comparision
s1='hello'
s2='hello'
s1==s2
# Out:
# True

# %%
s1='hello'
s2='Hello'
s1==s2
# Out:
# False

# %%
s1='hello'
s2='Hello'
s1.lower()==s2.lower()
# Out:
# True

# %%
reg_user=['pw',"PW",'pW']
new_user='PW1'
if new_user in reg_user:
    print("Already Exists")
else:
    print("User name is available")
# Out:
# User name is available

# %%
# String Ordering
name=['ayush','sanjay','aayush']
sorted(name)
# Out:
# ['aayush', 'ayush', 'sanjay']

# %%
name.sort()

# %%
name
# Out:
# ['aayush', 'ayush', 'sanjay']

# %%
#Common String operation
a="      pw          "

# %%
a
# Out:
# '      pw          '

# %%
a.strip() # It will remove trailing all spaces
# Out:
# 'pw'

# %%
# Uncessary space
b="banana    "
b.strip()
# Out:
# 'banana'

# %%
#String Splitting
data= "Ayush, data science, teacher"
b=data.split(",") # It will split the data on the basis of delimeter and will return list as a result

# %%
name=b[0]
course=b[1]
desi=b[2]

# %%
name
# Out:
# 'Ayush'

# %%
course
# Out:
# ' data science'

# %%
desi
# Out:
# ' teacher'

# %%
desi.strip()
# Out:
# 'teacher'

# %%
# Escape Sequence
# Special combination of characters used with in a string
a='''A 506,
Noida,
GB Nagar'''

# %%
a
# Out:
# 'A 506,\nNoida,\nGB Nagar'

# %%
print(a)
# Out:
# A 506,
# Noida,
# GB Nagar

# %%
a='''A 506,\nNoida,\nGB Nagar'''

# %%
a
# Out:
# 'A 506,\nNoida,\nGB Nagar'

# %%
print(a)
# Out:
# A 506,
# Noida,
# GB Nagar

# %%
#\t tab space
table="Name\tAge\tGrade\nAyush\t25\ta\nRahul\t34\ta"

print(table)
# Out:
# Name	Age	Grade
# Ayush	25	a
# Rahul	34	a

# %%
#Single Quote escpe
str1='I Can\'t play cricket'

# %%
str1
# Out:
# "I Can't play cricket"

# %%
#Carriage return \r >> moves the cursor to the beginig of line
print("Hi, Im Ayush Saxena, lives in noida")
print("Hi, \rIm Ayush Saxena, lives in noida")
# Out:
# Hi, Im Ayush Saxena, lives in noida
# Im Ayush Saxena, lives in noida

# %%
# String Formatting>> Creating string with placeholder for varibles
name="Ayush"
greetings=f"Hello {name}, how are you?" #fstring
print(greetings)
# Out:
# Hello Ayush, how are you?

# %%
#way 2
name="Ayush"
greetings="Hello %s, how are you?"%name
print(greetings)
# Out:
# Hello Ayush, how are you?

# %%
#.format
temp='Hello,{} welcome to {}'
msg=temp.format("Ayush","London")
print(msg)
# Out:
# Hello,Ayush welcome to London

# %%
c=30
print(f"{c} is equal to {(c*9/5)+32}F")
# Out:
# 30 is equal to 86.0F

# %%
s1='pwskills'
s1.startswith('p')
# Out:
# True

# %%
s1.startswith('aws')
# Out:
# False

# %%
s1.endswith('lls')
# Out:
# True

# %%
s1.endswith("lly")
# Out:
# False

# %%
# Alphanumeric
a="123hk"
a.isalnum()
# Out:
# True

# %%
s='pwskills'
len(s)
# Out:
# 8

# %%
count=0
for i in s:
    print(i)
    count+=1
print(count)
# Out:
# p
# w
# s
# k
# i
# l
# l
# s
# 8

# %%
for i in s:
    
    count+=1
    
print(count)
# Out:
# 24

# %%
a='ayush'
count=0
for i in a:
    count+=1
    
print(count)
# Out:
# 5

# %%
d={"a":1,"b":2}

# %%
d.get('name')

# %%
d
# Out:
# {'a': 1, 'b': 2}

# %%
d.get('name')

# %%
a=[1,2,3,4]

# %%
a.remove(2)

# %%
a
# Out:
# [1, 3, 4]
